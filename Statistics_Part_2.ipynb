# %% [markdown]
# # **📘 Theoretical Part (Hypothesis Testing & Statistical Concepts)**

# %% [markdown]
# 1. What is hypothesis testing in statistics?
#
#   Hypothesis testing is a statistical method used to make decisions or inferences about population parameters based on sample data. It involves:
#
# * Formulating two hypotheses:
#
#   * **Null Hypothesis (H₀):** Assumes no effect or no difference.
#   * **Alternative Hypothesis (H₁):** Indicates the presence of an effect or difference.
#
# * Using sample data to determine whether to reject H₀ in favor of H₁.
#
# ---
#
# 2. What is the null hypothesis, and how does it differ from the alternative hypothesis?
#
# * **Null Hypothesis (H₀):** A statement of no effect (e.g., “The mean weight of apples is 200g.”).
# * **Alternative Hypothesis (H₁ or Ha):** A statement that contradicts the null (e.g., “The mean weight is not 200g.”).
# * Hypothesis tests aim to gather enough evidence against H₀.
#
# ---
#
# 3. What is the significance level in hypothesis testing, and why is it important?
#
# * The **significance level (α)** is the probability of rejecting the null hypothesis when it is actually true (**Type I error**).
# * Common values: **0.05**, **0.01**, **0.10**.
# * Lower α → stricter decision threshold.
#
# ---
#
# 4. What does a P-value represent in hypothesis testing?
#
# * The **P-value** is the probability of obtaining a test statistic at least as extreme as the one observed, under the assumption that H₀ is true.
#
# ---
#
# 5. How do you interpret the P-value in hypothesis testing?
#
# * **P < α**: Reject H₀ (significant result).
# * **P ≥ α**: Fail to reject H₀ (not significant).
# * A **small P-value** suggests strong evidence against H₀.
#
# ---
#
# 6. What are Type 1 and Type 2 errors in hypothesis testing?
#
# | Type        | Error Description                                     |
# | ----------- | ----------------------------------------------------- |
# | Type I (α)  | Rejecting H₀ when it's true (False positive)          |
# | Type II (β) | Failing to reject H₀ when it's false (False negative) |
#
# ---
#
# 7. What is the difference between a one-tailed and a two-tailed test  in hypothesis testing?
#
# * **One-tailed test**: Tests deviation in one direction (e.g., greater than).
# * **Two-tailed test**: Tests deviation in both directions (e.g., not equal).
#
# ---
#
# 8. What is the Z-test, and when is it used in hypothesis testing?
#
# * A **Z-test** compares a sample mean to a known population mean when population standard deviation is known.
# * Used when **n > 30** (large sample) and population is normally distributed.
#
# ---
#
# 9. How do you calculate the Z-score, and what does it represent  in hypothesis testing?
#
# $$
# Z = \frac{(X - \mu)}{\sigma}
# $$
#
# * Represents how many standard deviations a value **X** is from the mean **μ**.
# * Useful for standardizing data.
#
# ---
#
# 10. What is the T-distribution, and when should it be used instead of the normal distribution?
#
# * The **T-distribution** is used when:
#
#   * Sample size is **small (n < 30)**.
#   * Population standard deviation is **unknown**.
# * T-distribution is wider and more variable than normal distribution.
#
# ---
#
# 11. What is the difference between a Z-test and a T-test?
#
# | Test   | Use Case                           | Known σ | Sample Size    |
# | ------ | ---------------------------------- | ------- | -------------- |
# | Z-test | Known population std. dev (σ)      | Yes     | Large (n > 30) |
# | T-test | Unknown σ and/or small sample size | No      | Small (n < 30) |
#
# ---
# 12. What is the T-test, and how is it used in hypothesis testing?
#
# * **T-test** checks if the means of two groups are statistically different.
# * Types:
#
#   * **One-sample**
#   * **Independent two-sample**
#   * **Paired sample**
#
# ---
#
# 13. What is the relationship between Z-test and T-test in hypothesis testing?
#
# * Both test means but differ in assumptions:
#
#   * Z-test: known σ
#   * T-test: unknown σ
# * T-test approximates Z-test as sample size increases.
#
# ---
#
# 14. What is a confidence interval, and how is it used to interpret statistical results?
#
# * A **confidence interval (CI)** gives a range of plausible values for a parameter.
# * E.g., 95% CI = we’re 95% confident the true mean lies in that range.
#
# ---
#
# 15. What is the margin of error, and how does it affect the confidence interval?
#
# * **Margin of Error (MoE)** is the maximum expected difference between the sample estimate and the population parameter.
# * CI = Estimate ± MoE
#
# ---
#
# 16. How is Bayes' Theorem used in statistics, and what is its significance?
#
# Bayes' Theorem:
#
# $$
# P(A|B) = \frac{P(B|A)P(A)}{P(B)}
# $$
#
# * Updates the probability of a hypothesis based on new evidence.
# * Used in:
#
#   * Spam filters
#   * Medical diagnostics
#   * Machine learning
#
# ---
#
# 17. What is the Chi-square distribution, and when is it used?
#
# * A **Chi-square (χ²) distribution** is used for **categorical data**.
# * Applications:
#
#   * Goodness-of-fit test
#   * Test of independence
#
# ---
#
# 18. What is the Chi-square goodness of fit test, and how is it applied?
#
# * Tests whether observed categorical frequencies match expected frequencies.
# * Formula:
#
# $$
# \chi^2 = \sum \frac{(O_i - E_i)^2}{E_i}
# $$
#
# ---
#
# 19. What is the F-distribution, and when is it used in hypothesis testing?
#
# * The **F-distribution** compares two variances.
# * Used in:
#
#   * ANOVA (analysis of variance)
#   * Regression models
#
# ---
#
# 20. What is an ANOVA test, and what are its assumptions?
#
# * **ANOVA** tests if three or more group means are equal.
# * Assumptions:
#
#   * Independence
#   * Normality
#   * Equal variances
#
# ---
#
# 21. What are the different types of ANOVA tests?
#
# | Type              | Description                     |
# | ----------------- | ------------------------------- |
# | One-way           | One independent variable        |
# | Two-way           | Two independent variables       |
# | Repeated measures | Same subjects tested repeatedly |
#
# ---
#
# 22. What is the F-test, and how does it relate to hypothesis testing?
#
# * An **F-test** compares variances of two populations.
# * If F-ratio is large, variances differ significantly.
# * It’s the basis of ANOVA.

# %% [markdown]
# # **📘 Practical Part - 1 (Hypothesis Testing & Statistical Concepts)**

# %% [markdown]
# 1.  Write a Python program to generate a random variable and display its value.

# %%
import random
random_variable = random.randint(1, 100)
print("Random Variable:", random_variable)
# Out:
# Random Variable: 37

# %% [markdown]
# 2. Generate a discrete uniform distribution using Python and plot the probability mass function (PMF).

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import randint

low, high = 1, 10
x = np.arange(low, high+1)
pmf = randint.pmf(x, low, high+1)

plt.bar(x, pmf)
plt.xlabel("Values")
plt.ylabel("PMF")
plt.title("Discrete Uniform Distribution")
plt.show()

# %% [markdown]
# 3.  Write a Python function to calculate the probability distribution function (PDF) of a Bernoulli distribution.

# %%
from scipy.stats import bernoulli
def bernoulli_pdf(p, x):
    return bernoulli.pmf(x, p)

p = 0.5
print("Bernoulli PDF (p=0.5):", bernoulli_pdf(p, 1))
# Out:
# Bernoulli PDF (p=0.5): 0.5

# %% [markdown]
# 4. Write a Python script to simulate a binomial distribution with n=10 and p=0.5, then plot its histogram.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import binom

n, p = 10, 0.5
data = binom.rvs(n, p, size=1000)

plt.hist(data, bins=range(n+2), density=True, edgecolor='black')
plt.title("Binomial Distribution Histogram")
plt.show()

# %% [markdown]
# 5. Create a Poisson distribution and visualize it using Python.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import poisson

mu = 4
x = np.arange(0, 15)
pmf = poisson.pmf(x, mu)

plt.bar(x, pmf)
plt.title("Poisson Distribution")
plt.show()

# %% [markdown]
# 6. Write a Python program to calculate and plot the cumulative distribution function (CDF) of a discrete
# uniform distribution.

# %%
from scipy.stats import randint
import numpy as np
import matplotlib.pyplot as plt

low, high = 1, 10
x = np.arange(low, high+1)
cdf = randint.cdf(x, low, high+1)

plt.plot(x, cdf, marker='o')
plt.title("CDF of Discrete Uniform Distribution")
plt.show()

# %% [markdown]
# 7. Generate a continuous uniform distribution using NumPy and visualize it.

# %%
import numpy as np
import matplotlib.pyplot as plt

data = np.random.uniform(0, 1, 1000)
plt.hist(data, bins=30, density=True)
plt.title("Continuous Uniform Distribution")
plt.show()

# %% [markdown]
# 8.  Simulate data from a normal distribution and plot its histogram.

# %%
import numpy as np
import matplotlib.pyplot as plt

data = np.random.normal(0, 1, 1000)
plt.hist(data, bins=30, density=True, alpha=0.6)
plt.title("Normal Distribution Histogram")
plt.show()

# %% [markdown]
# 9.  Write a Python function to calculate Z-scores from a dataset and plot them.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import zscore

data = np.random.normal(50, 10, 100)
z_scores = zscore(data)

plt.hist(z_scores, bins=20, edgecolor='black')
plt.title("Z-score Distribution")
plt.show()

# %% [markdown]
# 10.  Implement the Central Limit Theorem (CLT) using Python for a non-normal distribution.

# %%
import numpy as np
import matplotlib.pyplot as plt

samples = [np.mean(np.random.exponential(scale=2, size=30)) for _ in range(1000)]
plt.hist(samples, bins=30, density=True)
plt.title("Central Limit Theorem in Action")
plt.show()

# %% [markdown]
# 11. Simulate multiple samples from a normal distribution and verify the Central Limit Theorem.

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Step 1: Generate a non-normal distribution (Exponential)
population = np.random.exponential(scale=2, size=10000)

# Step 2: Draw multiple samples and compute means
sample_size = 30
num_samples = 1000
sample_means = [np.mean(np.random.choice(population, size=sample_size)) for _ in range(num_samples)]

# Step 3: Plot the original population and sample means
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

# Original population distribution
sns.histplot(population, bins=50, kde=True, color='blue', ax=axes[0])
axes[0].set_title("Original Population (Exponential)")

# Sample mean distribution
sns.histplot(sample_means, bins=30, kde=True, color='green', ax=axes[1])
axes[1].set_title("Sample Means Distribution (CLT Verification)")

plt.tight_layout()
plt.show()

# %% [markdown]
# 12.  Write a Python function to calculate and plot the standard normal distribution (mean = 0, std = 1).

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

def plot_standard_normal_distribution():
    # Define the range of x values
    x = np.linspace(-4, 4, 1000)

    # Calculate the PDF of the standard normal distribution
    y = norm.pdf(x, loc=0, scale=1)

    # Plot the distribution
    plt.plot(x, y, label='Standard Normal PDF', color='blue')
    plt.title('Standard Normal Distribution (mean = 0, std = 1)')
    plt.xlabel('x')
    plt.ylabel('Probability Density')
    plt.grid(True)
    plt.legend()
    plt.show()

# Call the function
plot_standard_normal_distribution()

# %% [markdown]
# 13. Generate random variables and calculate their corresponding probabilities using the binomial distribution.
#
#   - The binomial distribution models the number of successes in a fixed number of independent trials, each with the same probability of success.
#
# Formula for binomial probability:
#
# 𝑃
# (
# 𝑋
# =
# 𝑘
# )
# =
# (
# 𝑛
# 𝑘
# )
# 𝑝
# 𝑘
# (
# 1
# −
# 𝑝
# )
# 𝑛
# −
# 𝑘

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import binom

# Parameters
n = 10  # Number of trials
p = 0.5  # Probability of success

# Generate random binomial variables
random_variables = np.random.binomial(n, p, 1000)

# Calculate probability mass function (PMF)
x = np.arange(0, n + 1)
pmf = binom.pmf(x, n, p)

# Plot the PMF
plt.bar(x, pmf, color='blue', alpha=0.7)
plt.xlabel("Number of Successes (k)")
plt.ylabel("Probability")
plt.title("Binomial Distribution PMF (n=10, p=0.5)")
plt.show()

# %% [markdown]
# 14. Write a Python program to calculate the Z-score for a given data point and compare it to a standard normal
# distribution.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Sample dataset
data = np.random.normal(50, 10, 100)  # Generate 100 random values with mean=50, std=10

# Given data point
X = 60

# Calculate mean and standard deviation
mean = np.mean(data)
std_dev = np.std(data)

# Compute the Z-score
z_score = (X - mean) / std_dev
print(f"Data Point: {X}, Mean: {mean:.2f}, Standard Deviation: {std_dev:.2f}, Z-score: {z_score:.2f}")

# Plot the Standard Normal Distribution
x_values = np.linspace(-3, 3, 1000)
y_values = norm.pdf(x_values, 0, 1)

plt.plot(x_values, y_values, label="Standard Normal Distribution", color="blue")
plt.axvline(z_score, color='red', linestyle='dashed', label=f"Z-score = {z_score:.2f}")
plt.xlabel("Z-score")
plt.ylabel("Probability Density")
plt.title("Comparison of Z-score with Standard Normal Distribution")
plt.legend()
plt.show()
# Out:
# Data Point: 60, Mean: 49.05, Standard Deviation: 10.53, Z-score: 1.04

# %% [markdown]
# 15.  Implement hypothesis testing using Z-statistics for a sample dataset.

# %%
import numpy as np
from scipy.stats import norm

# Given data
sample = np.array([90, 110, 95, 105, 100, 98, 102, 97, 99, 103])  # Sample sales data
population_mean = 100  # Claimed mean
population_std = 10     # Known standard deviation
sample_size = len(sample)

# Step 1: Compute Sample Mean
sample_mean = np.mean(sample)

# Step 2: Compute Z-score
z_score = (sample_mean - population_mean) / (population_std / np.sqrt(sample_size))

# Step 3: Compute P-value
p_value = 2 * (1 - norm.cdf(abs(z_score)))  # Two-tailed test

# Step 4: Conclusion
alpha = 0.05  # Significance level
if p_value < alpha:
    print(f"Reject the null hypothesis (H0). Z-score: {z_score:.2f}, P-value: {p_value:.4f}")
else:
    print(f"Fail to reject the null hypothesis (H0). Z-score: {z_score:.2f}, P-value: {p_value:.4f}")
# Out:
# Fail to reject the null hypothesis (H0). Z-score: -0.03, P-value: 0.9748

# %% [markdown]
# 16. Create a confidence interval for a dataset using Python and interpret the result.

# %%
import numpy as np
import scipy.stats as stats

# Step 1: Generate sample data
data = np.random.normal(loc=100, scale=15, size=30)  # Mean=100, Std=15, Sample Size=30

# Step 2: Compute sample statistics
sample_mean = np.mean(data)
sample_std = np.std(data, ddof=1)  # Use ddof=1 for sample standard deviation

# Step 3: Set confidence level (95%) and find Z-score
confidence_level = 0.95
z_score = stats.norm.ppf(1 - (1 - confidence_level) / 2)

# Step 4: Compute margin of error
margin_of_error = z_score * (sample_std / np.sqrt(len(data)))

# Step 5: Calculate confidence interval
lower_bound = sample_mean - margin_of_error
upper_bound = sample_mean + margin_of_error

# Display results
print(f"Sample Mean: {sample_mean:.2f}")
print(f"95% Confidence Interval: ({lower_bound:.2f}, {upper_bound:.2f})")
# Out:
# Sample Mean: 96.10
# 95% Confidence Interval: (90.97, 101.23)

# %% [markdown]
# 17. Generate data from a normal distribution, then calculate and interpret the confidence interval for its mean.
#
#
#    - A confidence interval (CI) provides a range of values that is likely to contain the true population mean. It is calculated as:
#
# 𝐶
# 𝐼
# =
# 𝑋
# ˉ
# ±
# 𝑍
# (
# 𝜎
# 𝑛
# )

# %%
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

# Step 1: Generate data from a normal distribution
data = np.random.normal(loc=100, scale=15, size=50)  # Mean=100, Std=15, Sample Size=50

# Step 2: Compute sample mean and standard deviation
sample_mean = np.mean(data)
sample_std = np.std(data, ddof=1)  # Use ddof=1 for sample standard deviation

# Step 3: Set confidence level (95%) and find Z-score
confidence_level = 0.95
z_score = stats.norm.ppf(1 - (1 - confidence_level) / 2)

# Step 4: Compute margin of error
margin_of_error = z_score * (sample_std / np.sqrt(len(data)))

# Step 5: Calculate confidence interval
lower_bound = sample_mean - margin_of_error
upper_bound = sample_mean + margin_of_error

# Step 6: Print results
print(f"Sample Mean: {sample_mean:.2f}")
print(f"95% Confidence Interval: ({lower_bound:.2f}, {upper_bound:.2f})")

# Step 7: Visualize the confidence interval
plt.hist(data, bins=30, density=True, alpha=0.6, color="blue")
plt.axvline(lower_bound, color="red", linestyle="dashed", label=f"Lower Bound: {lower_bound:.2f}")
plt.axvline(upper_bound, color="green", linestyle="dashed", label=f"Upper Bound: {upper_bound:.2f}")
plt.axvline(sample_mean, color="black", linestyle="dashed", label=f"Mean: {sample_mean:.2f}")
plt.legend()
plt.title("Confidence Interval Visualization")
plt.show()
# Out:
# Sample Mean: 100.79
# 95% Confidence Interval: (95.61, 105.96)

# %% [markdown]
# 18.  Write a Python script to calculate and visualize the probability density function (PDF) of a normal distribution.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Step 1: Define parameters
mu = 0    # Mean
sigma = 1  # Standard Deviation

# Step 2: Generate values for x-axis
x = np.linspace(mu - 4*sigma, mu + 4*sigma, 1000)  # Range of values

# Step 3: Compute Probability Density Function
pdf = norm.pdf(x, mu, sigma)

# Step 4: Plot the Normal Distribution PDF
plt.plot(x, pdf, color="blue", label="Normal Distribution PDF")
plt.xlabel("x values")
plt.ylabel("Probability Density")
plt.title("Probability Density Function of Normal Distribution")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# 19.  Use Python to calculate and interpret the cumulative distribution function (CDF) of a Poisson distribution.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import poisson

# Step 1: Define parameters
lambda_value = 4  # Mean occurrences (Poisson rate)
x_values = np.arange(0, 15, 1)  # Possible values of X

# Step 2: Compute Poisson CDF
cdf_values = poisson.cdf(x_values, lambda_value)

# Step 3: Plot the Poisson CDF
plt.plot(x_values, cdf_values, marker='o', linestyle='solid', color="blue", label="Poisson CDF")
plt.xlabel("Number of Events (x)")
plt.ylabel("Cumulative Probability")
plt.title("Cumulative Distribution Function (CDF) of Poisson Distribution")
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# 20. Simulate a random variable using a continuous uniform distribution and calculate its expected value.

# %%
import numpy as np

# Define the range of the continuous uniform distribution
a = 5   # lower bound
b = 15  # upper bound

# Simulate 1000 random values from the distribution
samples = np.random.uniform(low=a, high=b, size=1000)

# Calculate the expected value
expected_value = np.mean(samples)

print("Expected Value (Simulated Mean):", expected_value)
print("Theoretical Expected Value:", (a + b) / 2)
# Out:
# Expected Value (Simulated Mean): 10.010656130559338
# Theoretical Expected Value: 10.0

# %% [markdown]
# 21.  Write a Python program to compare the standard deviations of two datasets and visualize the difference.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate two datasets
dataset1 = np.random.normal(loc=50, scale=5, size=1000)   # Mean=50, Std=5
dataset2 = np.random.normal(loc=50, scale=10, size=1000)  # Mean=50, Std=10

# Calculate standard deviations
std1 = np.std(dataset1)
std2 = np.std(dataset2)

# Display results
print("Standard Deviation of Dataset 1:", std1)
print("Standard Deviation of Dataset 2:", std2)

# Visualization
datasets = ['Dataset 1', 'Dataset 2']
std_values = [std1, std2]

plt.bar(datasets, std_values, color=['skyblue', 'salmon'])
plt.title('Comparison of Standard Deviations')
plt.ylabel('Standard Deviation')
plt.grid(axis='y')
plt.show()
# Out:
# Standard Deviation of Dataset 1: 5.111859372101952
# Standard Deviation of Dataset 2: 10.160196325242744

# %% [markdown]
# 22.  Calculate the range and interquartile range (IQR) of a dataset generated from a normal distribution.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate random data from a normal distribution
data = np.random.normal(loc=100, scale=15, size=1000)

# Calculate the range
data_range = np.max(data) - np.min(data)

# Calculate the IQR
q1 = np.percentile(data, 25)
q3 = np.percentile(data, 75)
iqr = q3 - q1

# Print the results
print("Range of the dataset:", data_range)
print("Interquartile Range (IQR):", iqr)

# Optional: Boxplot for visualizing IQR
plt.boxplot(data, vert=False)
plt.title("Boxplot of Normally Distributed Data")
plt.xlabel("Value")
plt.grid(True)
plt.show()
# Out:
# Range of the dataset: 81.06158964783239
# Interquartile Range (IQR): 19.296648531292732

# %% [markdown]
# 23.  Implement Z-score normalization on a dataset and visualize its transformation.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import zscore

# Generate random data (normal distribution with mean ≠ 0 and std ≠ 1)
data = np.random.normal(loc=100, scale=20, size=1000)

# Apply Z-score normalization
normalized_data = zscore(data)

# Plot original vs normalized data (histograms)
plt.figure(figsize=(12, 5))

# Original data
plt.subplot(1, 2, 1)
plt.hist(data, bins=30, color='skyblue', edgecolor='black')
plt.title('Original Data')
plt.xlabel('Value')
plt.ylabel('Frequency')

# Normalized data
plt.subplot(1, 2, 2)
plt.hist(normalized_data, bins=30, color='salmon', edgecolor='black')
plt.title('Z-score Normalized Data')
plt.xlabel('Z-score')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# Print summary statistics
print("Original Data → Mean:", np.mean(data), "Std Dev:", np.std(data))
print("Normalized Data → Mean:", np.mean(normalized_data), "Std Dev:", np.std(normalized_data))
# Out:
# Original Data → Mean: 99.3671015903937 Std Dev: 19.66778295061096
# Normalized Data → Mean: -1.2079226507921704e-16 Std Dev: 1.0

# %% [markdown]
# 24.  Write a Python function to calculate the skewness and kurtosis of a dataset generated from a normal
# distribution.

# %%
import numpy as np
from scipy.stats import skew, kurtosis

def calculate_skewness_kurtosis(size=1000, mean=0, std=1):
    # Generate normally distributed data
    data = np.random.normal(loc=mean, scale=std, size=size)

    # Calculate skewness and kurtosis
    skewness = skew(data)
    kurt = kurtosis(data)  # Fisher's definition (normal = 0)

    # Print the results
    print("Skewness:", skewness)
    print("Kurtosis:", kurt)

# Call the function
calculate_skewness_kurtosis()
# Out:
# Skewness: -0.04872574112928876
# Kurtosis: 0.17089091814707968

# %% [markdown]
# # **Practical Part - 2** ▶

# %% [markdown]
# 1. Write a Python program to perform a Z-test for comparing a sample mean to a known population mean and
# interpret the results.

# %%
import numpy as np
from scipy.stats import norm

# Sample dataset (daily sales)
sample = np.array([90, 110, 95, 105, 100, 98, 102, 97, 99, 103])  # 10 data points
population_mean = 100  # Claimed mean
population_std = 10     # Known standard deviation
sample_size = len(sample)

# Compute Sample Mean
sample_mean = np.mean(sample)

# Compute Z-score
z_score = (sample_mean - population_mean) / (population_std / np.sqrt(sample_size))

# Compute P-value
p_value = 2 * (1 - norm.cdf(abs(z_score)))  # Two-tailed test

# Define significance level
alpha = 0.05

# Interpretation
if p_value < alpha:
    print(f"Reject the null hypothesis (H₀). Z-score: {z_score:.2f}, P-value: {p_value:.4f}")
else:
    print(f"Fail to reject the null hypothesis (H₀). Z-score: {z_score:.2f}, P-value: {p_value:.4f}")
# Out:
# Fail to reject the null hypothesis (H₀). Z-score: -0.03, P-value: 0.9748

# %% [markdown]
# 2.  Simulate random data to perform hypothesis testing and calculate the corresponding P-value using Python.

# %%
import numpy as np
from scipy.stats import ttest_1samp

# Step 1: Generate random data from a normal distribution
np.random.seed(42)  # For reproducibility
sample_data = np.random.normal(loc=100, scale=15, size=30)  # Mean=100, Std=15, Sample Size=30

# Step 2: Define population mean (claimed value)
population_mean = 100

# Step 3: Perform one-sample t-test
t_stat, p_value = ttest_1samp(sample_data, population_mean)

# Step 4: Interpretation
alpha = 0.05  # Significance level
if p_value < alpha:
    print(f"Reject the null hypothesis (H₀). T-statistic: {t_stat:.2f}, P-value: {p_value:.4f}")
else:
    print(f"Fail to reject the null hypothesis (H₀). T-statistic: {t_stat:.2f}, P-value: {p_value:.4f}")
# Out:
# Fail to reject the null hypothesis (H₀). T-statistic: -1.15, P-value: 0.2616

# %% [markdown]
# 3.  Implement a one-sample Z-test using Python to compare the sample mean with the population mean.

# %%
import numpy as np
from scipy.stats import norm

# Sample dataset (daily sales)
sample = np.array([90, 110, 95, 105, 100, 98, 102, 97, 99, 103])  # 10 data points
population_mean = 100  # Claimed mean
population_std = 10     # Known standard deviation
sample_size = len(sample)

# Compute Sample Mean
sample_mean = np.mean(sample)

# Compute Z-score
z_score = (sample_mean - population_mean) / (population_std / np.sqrt(sample_size))

# Compute P-value
p_value = 2 * (1 - norm.cdf(abs(z_score)))  # Two-tailed test

# Define significance level
alpha = 0.05

# Interpretation
if p_value < alpha:
    print(f"Reject the null hypothesis (H₀). Z-score: {z_score:.2f}, P-value: {p_value:.4f}")
else:
    print(f"Fail to reject the null hypothesis (H₀). Z-score: {z_score:.2f}, P-value: {p_value:.4f}")
# Out:
# Fail to reject the null hypothesis (H₀). Z-score: -0.03, P-value: 0.9748

# %% [markdown]
# 4.  Perform a two-tailed Z-test using Python and visualize the decision region on a plot.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Step 1: Sample Data
sample = np.array([92, 108, 95, 107, 101, 99, 105, 97, 100, 102])  # Sample values
population_mean = 100  # Claimed mean
population_std = 10     # Known standard deviation
sample_size = len(sample)

# Step 2: Compute Sample Mean
sample_mean = np.mean(sample)

# Step 3: Compute Z-score
z_score = (sample_mean - population_mean) / (population_std / np.sqrt(sample_size))

# Step 4: Compute P-value
p_value = 2 * (1 - norm.cdf(abs(z_score)))  # Two-tailed test

# Step 5: Define significance level
alpha = 0.05  # 95% confidence level
z_critical = norm.ppf(1 - alpha / 2)  # Z-critical value for 95% CI (±1.96)

# Step 6: Interpretation
if abs(z_score) > z_critical:
    print(f"Reject the null hypothesis (H₀). Z-score: {z_score:.2f}, P-value: {p_value:.4f}")
else:
    print(f"Fail to reject the null hypothesis (H₀). Z-score: {z_score:.2f}, P-value: {p_value:.4f}")

# Step 7: Visualization of Decision Regions
x_values = np.linspace(-3, 3, 1000)
y_values = norm.pdf(x_values, 0, 1)

plt.plot(x_values, y_values, color="blue", label="Standard Normal Distribution")

# Highlight rejection regions
plt.fill_between(x_values, y_values, where=(x_values < -z_critical) | (x_values > z_critical), color='red', alpha=0.5, label="Rejection Region")

# Mark calculated Z-score
plt.axvline(z_score, color="black", linestyle="dashed", label=f"Z-score: {z_score:.2f}")

plt.axvline(-z_critical, color="green", linestyle="dashed", label="Critical Value: -1.96")
plt.axvline(z_critical, color="green", linestyle="dashed", label="Critical Value: +1.96")

plt.xlabel("Z-score")
plt.ylabel("Probability Density")
plt.title("Two-Tailed Z-test Decision Region")
plt.legend()
plt.grid()
plt.show()
# Out:
# Fail to reject the null hypothesis (H₀). Z-score: 0.19, P-value: 0.8495

# %% [markdown]
# 5. Create a Python function that calculates and visualizes Type 1 and Type 2 errors during hypothesis testing.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

def plot_type1_type2_errors(mu_null=0, mu_alt=1, sigma=1, alpha=0.05):
    """
    Visualizes Type 1 and Type 2 errors on a normal distribution curve.

    Parameters:
    - mu_null: Mean under null hypothesis (H0)
    - mu_alt: Mean under alternative hypothesis (H1)
    - sigma: Standard deviation
    - alpha: Significance level (default: 0.05)
    """
    # Compute critical value for rejection of H0
    critical_value = norm.ppf(1 - alpha, loc=mu_null, scale=sigma)

    # Generate x-values
    x = np.linspace(mu_null - 4*sigma, mu_alt + 4*sigma, 1000)

    # Compute probability density functions (PDFs)
    y_null = norm.pdf(x, mu_null, sigma)  # H0 distribution
    y_alt = norm.pdf(x, mu_alt, sigma)    # H1 distribution

    # Plot the distributions
    plt.plot(x, y_null, color='blue', label="Null Distribution (H₀)")
    plt.plot(x, y_alt, color='green', label="Alternative Distribution (H₁)")

    # Shade Type 1 Error (alpha)
    plt.fill_between(x, y_null, where=(x > critical_value), color='red', alpha=0.5, label="Type 1 Error (α)")

    # Shade Type 2 Error (beta)
    plt.fill_between(x, y_alt, where=(x < critical_value), color='purple', alpha=0.5, label="Type 2 Error (β)")

    # Add reference lines
    plt.axvline(critical_value, color='black', linestyle='dashed', label="Critical Value")

    plt.xlabel("Test Statistic")
    plt.ylabel("Probability Density")
    plt.title("Type 1 & Type 2 Errors in Hypothesis Testing")
    plt.legend()
    plt.grid()
    plt.show()

# Call function to plot Type 1 & Type 2 errors
plot_type1_type2_errors()

# %% [markdown]
# 6.  Write a Python program to perform an independent T-test and interpret the results.

# %%
import numpy as np
from scipy.stats import ttest_ind

# Step 1: Generate two independent sample datasets
np.random.seed(42)  # Ensure reproducibility
group_A = np.random.normal(loc=100, scale=15, size=30)  # Mean=100, Std=15
group_B = np.random.normal(loc=110, scale=15, size=30)  # Mean=110, Std=15

# Step 2: Perform independent T-test
t_stat, p_value = ttest_ind(group_A, group_B)

# Step 3: Interpretation
alpha = 0.05  # Significance level
if p_value < alpha:
    print(f"Reject the null hypothesis (H₀). T-statistic: {t_stat:.2f}, P-value: {p_value:.4f}")
else:
    print(f"Fail to reject the null hypothesis (H₀). T-statistic: {t_stat:.2f}, P-value: {p_value:.4f}")
# Out:
# Reject the null hypothesis (H₀). T-statistic: -3.10, P-value: 0.0030

# %% [markdown]
# 7.  Perform a paired sample T-test using Python and visualize the comparison results.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import ttest_rel

# Step 1: Generate paired sample data (Before and After training scores)
np.random.seed(42)  # For reproducibility
before_training = np.random.normal(loc=75, scale=10, size=30)  # Test scores before training
after_training = before_training + np.random.normal(loc=5, scale=5, size=30)  # Test scores after training

# Step 2: Perform Paired Sample T-test
t_stat, p_value = ttest_rel(before_training, after_training)

# Step 3: Interpretation
alpha = 0.05  # Significance level
if p_value < alpha:
    print(f"Reject the null hypothesis (H₀). T-statistic: {t_stat:.2f}, P-value: {p_value:.4f} → Significant difference!")
else:
    print(f"Fail to reject the null hypothesis (H₀). T-statistic: {t_stat:.2f}, P-value: {p_value:.4f} → No significant difference.")

# Step 4: Visualization using a boxplot
plt.figure(figsize=(8, 5))
plt.boxplot([before_training, after_training], labels=['Before Training', 'After Training'], patch_artist=True)
plt.title("Paired Sample T-Test: Before vs. After Training")
plt.ylabel("Test Scores")
plt.grid()
plt.show()
# Out:
# Reject the null hypothesis (H₀). T-statistic: -5.17, P-value: 0.0000 → Significant difference!
# <ipython-input-32-ed1b34f801a6>:22: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([before_training, after_training], labels=['Before Training', 'After Training'], patch_artist=True)

# %% [markdown]
# 8. Simulate data and perform both Z-test and T-test, then compare the results using Python.

# %%
import numpy as np
from scipy.stats import ttest_1samp, norm

# Step 1: Generate random sample data
np.random.seed(42)  # Ensure reproducibility
sample_data = np.random.normal(loc=100, scale=15, size=30)  # Mean=100, Std=15, Sample Size=30

# Population parameters (for Z-test)
population_mean = 100
population_std = 15  # Known population standard deviation

# Step 2: Perform Z-test (assuming known population std)
sample_mean = np.mean(sample_data)
z_score = (sample_mean - population_mean) / (population_std / np.sqrt(len(sample_data)))
p_value_z = 2 * (1 - norm.cdf(abs(z_score)))  # Two-tailed test

# Step 3: Perform T-test (assuming unknown population std)
t_stat, p_value_t = ttest_1samp(sample_data, population_mean)

# Step 4: Display results
print(f"Z-test results: Z-score = {z_score:.2f}, P-value = {p_value_z:.4f}")
print(f"T-test results: T-statistic = {t_stat:.2f}, P-value = {p_value_t:.4f}")

# Step 5: Compare Results
if p_value_z < 0.05:
    print("Z-test: Reject the null hypothesis (significant difference).")
else:
    print("Z-test: Fail to reject the null hypothesis (no significant difference).")

if p_value_t < 0.05:
    print("T-test: Reject the null hypothesis (significant difference).")
else:
    print("T-test: Fail to reject the null hypothesis (no significant difference).")
# Out:
# Z-test results: Z-score = -1.03, P-value = 0.3028
# T-test results: T-statistic = -1.15, P-value = 0.2616
# Z-test: Fail to reject the null hypothesis (no significant difference).
# T-test: Fail to reject the null hypothesis (no significant difference).

# %% [markdown]
# 9. Write a Python function to calculate the confidence interval for a sample mean and explain its significance.

# %%
import numpy as np
import scipy.stats as stats

def calculate_confidence_interval(data, confidence=0.95):
    """
    Calculates the confidence interval for a sample mean.

    Parameters:
    - data: list or numpy array (sample data)
    - confidence: confidence level (default: 95%)

    Returns:
    - (lower_bound, upper_bound): Tuple representing the confidence interval
    """

    sample_mean = np.mean(data)
    sample_std = np.std(data, ddof=1)  # Use ddof=1 for sample standard deviation
    sample_size = len(data)

    # Compute Z-score for confidence level
    z_score = stats.norm.ppf(1 - (1 - confidence) / 2)

    # Compute margin of error
    margin_of_error = z_score * (sample_std / np.sqrt(sample_size))

    # Compute confidence interval bounds
    lower_bound = sample_mean - margin_of_error
    upper_bound = sample_mean + margin_of_error

    return (lower_bound, upper_bound)

# Example usage:
data = np.random.normal(loc=100, scale=15, size=30)  # Generating sample data
ci = calculate_confidence_interval(data)

print(f"95% Confidence Interval: ({ci[0]:.2f}, {ci[1]:.2f})")
# Out:
# 95% Confidence Interval: (93.18, 103.18)

# %% [markdown]
# 10.  Write a Python program to calculate the margin of error for a given confidence level using sample data.

# %%
import numpy as np
import scipy.stats as stats

def calculate_margin_of_error(data, confidence=0.95):
    """
    Calculates the margin of error for a given confidence level using sample data.

    Parameters:
    - data: list or numpy array (sample data)
    - confidence: confidence level (default: 95%)

    Returns:
    - Margin of Error (MOE)
    """

    sample_mean = np.mean(data)
    sample_std = np.std(data, ddof=1)  # Use ddof=1 for sample standard deviation
    sample_size = len(data)

    # Compute Z-score for confidence level
    z_score = stats.norm.ppf(1 - (1 - confidence) / 2)

    # Compute margin of error
    margin_of_error = z_score * (sample_std / np.sqrt(sample_size))

    return margin_of_error

# Example usage:
data = np.random.normal(loc=100, scale=15, size=30)  # Generate sample data
moe = calculate_margin_of_error(data)

print(f"Margin of Error for 95% confidence: {moe:.2f}")
# Out:
# Margin of Error for 95% confidence: 5.32

# %% [markdown]
# 11.  Implement a Bayesian inference method using Bayes' Theorem in Python and explain the process.

# %%
def bayes_theorem(prior, likelihood, marginal):
    """
    Computes the posterior probability using Bayes' Theorem.

    Parameters:
    - prior: P(A) - Prior probability
    - likelihood: P(B | A) - Probability of B given A is true
    - marginal: P(B) - Total probability of observing B

    Returns:
    - Posterior probability P(A | B)
    """
    return (likelihood * prior) / marginal

# Given Data
prior_prob = 0.02  # P(Disease)
likelihood = 0.90  # P(Positive Test | Disease)
false_positive_rate = 0.05  # P(Positive Test | No Disease)
no_disease_prob = 1 - prior_prob  # P(No Disease)

# Compute Marginal Probability P(Positive Test)
marginal_prob = (likelihood * prior_prob) + (false_positive_rate * no_disease_prob)

# Compute Posterior Probability P(Disease | Positive Test)
posterior_prob = bayes_theorem(prior_prob, likelihood, marginal_prob)

print(f"Probability of having disease given a positive test: {posterior_prob:.4f}")
# Out:
# Probability of having disease given a positive test: 0.2687

# %% [markdown]
# 12.  Perform a Chi-square test for independence between two categorical variables in Python.

# %%
import numpy as np
import scipy.stats as stats

# Step 1: Create an observed frequency table
observed = np.array([[50, 30],  # Male choosing Product A & B
                     [20, 40]]) # Female choosing Product A & B

# Step 2: Perform Chi-square test
chi2_stat, p_value, dof, expected = stats.chi2_contingency(observed)

# Step 3: Display results
print(f"Chi-square Statistic: {chi2_stat:.2f}")
print(f"P-value: {p_value:.4f}")
print(f"Degrees of Freedom: {dof}")
print(f"Expected Frequencies:\n{expected}")

# Step 4: Interpretation
alpha = 0.05  # Significance level
if p_value < alpha:
    print("Reject the null hypothesis (H₀): There is a significant association between Gender and Product Preference.")
else:
    print("Fail to reject the null hypothesis (H₀): Gender and Product Preference are independent.")
# Out:
# Chi-square Statistic: 10.53
# P-value: 0.0012
# Degrees of Freedom: 1
# Expected Frequencies:
# [[40. 40.]
#  [30. 30.]]
# Reject the null hypothesis (H₀): There is a significant association between Gender and Product Preference.

# %% [markdown]
# 13. Write a Python program to calculate the expected frequencies for a Chi-square test based on observed
# data.

# %%
import numpy as np
import scipy.stats as stats

def calculate_expected_frequencies(observed):
    """
    Computes expected frequencies for a Chi-square test.

    Parameters:
    - observed: 2D NumPy array (observed frequency table)

    Returns:
    - Expected frequencies as a 2D NumPy array
    """
    chi2_stat, p_value, dof, expected = stats.chi2_contingency(observed)
    return expected

# Example observed frequency table
observed_data = np.array([[50, 30],  # Row 1
                          [20, 40]]) # Row 2

# Compute expected frequencies
expected_frequencies = calculate_expected_frequencies(observed_data)

# Print expected frequencies
print("Expected Frequencies:")
print(expected_frequencies)
# Out:
# Expected Frequencies:
# [[40. 40.]
#  [30. 30.]]

# %% [markdown]
# 14. Perform a goodness-of-fit test using Python to compare the observed data to an expected distribution.

# %%
import numpy as np
import scipy.stats as stats

# Step 1: Define Observed Frequencies
observed = np.array([50, 30, 20])  # Actual survey responses for products A, B, C

# Step 2: Adjust Expected Frequencies to Match Observed Total
expected_total = np.sum(observed)
expected = np.array([expected_total / len(observed)] * len(observed))  # Equal distribution

# Step 3: Perform the Chi-square goodness-of-fit test
chi2_stat, p_value = stats.chisquare(observed, expected)

# Step 4: Display results
print(f"Chi-square Statistic: {chi2_stat:.2f}")
print(f"P-value: {p_value:.4f}")

# Step 5: Interpretation
alpha = 0.05  # Significance level
if p_value < alpha:
    print("Reject the null hypothesis (H₀): The observed data does NOT fit the expected distribution.")
else:
    print("Fail to reject the null hypothesis (H₀): The observed data fits the expected distribution.")
# Out:
# Chi-square Statistic: 14.00
# P-value: 0.0009
# Reject the null hypothesis (H₀): The observed data does NOT fit the expected distribution.
